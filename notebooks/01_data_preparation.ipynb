# %% [markdown]
# # Data Preparation
# Use this notebook to organize your dataset directory structure.

# %%
import os

# Define raw data path
raw_path = "../data/raw"
os.makedirs(raw_path, exist_ok=True)

print(f"Directory checked: {raw_path}")
print("Please manually organize your audio files in subfolders inside this directory per speaker:")
print("e.g. data/raw/person_1/audio.wav")
