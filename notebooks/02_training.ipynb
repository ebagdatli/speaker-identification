# %% [markdown]
# # Model Training
# Train the Speaker Encoder using Triplet Loss.

# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('..'))

from src.training.train import train

# %%
# Configuration
DATA_PATH = "../data/raw"
MODEL_PATH = "../models/speaker_encoder.pt"
EPOCHS = 50
BATCH_SIZE = 4

# Start Training
if os.path.exists(DATA_PATH) and len(os.listdir(DATA_PATH)) > 0:
    train(DATA_PATH, MODEL_PATH, EPOCHS, BATCH_SIZE)
else:
    print("Please add data to data/raw first.")
# Out:
# Using device: cpu
# Starting training for 50 epochs...
# Epoch 1/50: 100%|██████████| 6/6 [00:07<00:00,  1.19s/it, loss=0.858]
# Epoch 1 Average Loss: 0.9719
# Model saved to ../models/speaker_encoder.pt
# Epoch 2/50: 100%|██████████| 6/6 [00:07<00:00,  1.17s/it, loss=1.03]
# Epoch 2 Average Loss: 0.9371
# Model saved to ../models/speaker_encoder.pt
# Epoch 3/50: 100%|██████████| 6/6 [00:07<00:00,  1.19s/it, loss=1]
# Epoch 3 Average Loss: 0.9731
# Model saved to ../models/speaker_encoder.pt
# Epoch 4/50: 100%|██████████| 6/6 [00:07<00:00,  1.19s/it, loss=1]
# Epoch 4 Average Loss: 0.9993
# Model saved to ../models/speaker_encoder.pt
# Epoch 5/50: 100%|██████████| 6/6 [00:07<00:00,  1.18s/it, loss=1]
# Epoch 5 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 6/50: 100%|██████████| 6/6 [00:07<00:00,  1.22s/it, loss=0.999]
# Epoch 6 Average Loss: 0.9998
# Model saved to ../models/speaker_encoder.pt
# Epoch 7/50: 100%|██████████| 6/6 [00:08<00:00,  1.36s/it, loss=1]
# Epoch 7 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 8/50: 100%|██████████| 6/6 [00:08<00:00,  1.38s/it, loss=0.999]
# Epoch 8 Average Loss: 0.9998
# Model saved to ../models/speaker_encoder.pt
# Epoch 9/50: 100%|██████████| 6/6 [00:08<00:00,  1.35s/it, loss=1]
# Epoch 9 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 10/50: 100%|██████████| 6/6 [00:08<00:00,  1.37s/it, loss=1]
# Epoch 10 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 11/50: 100%|██████████| 6/6 [00:08<00:00,  1.40s/it, loss=1]
# Epoch 11 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 12/50: 100%|██████████| 6/6 [00:08<00:00,  1.41s/it, loss=1]
# Epoch 12 Average Loss: 1.0001
# Model saved to ../models/speaker_encoder.pt
# Epoch 13/50: 100%|██████████| 6/6 [00:08<00:00,  1.44s/it, loss=1]
# Epoch 13 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 14/50: 100%|██████████| 6/6 [00:08<00:00,  1.48s/it, loss=0.999]
# Epoch 14 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 15/50: 100%|██████████| 6/6 [00:08<00:00,  1.44s/it, loss=1]
# Epoch 15 Average Loss: 0.9997
# Model saved to ../models/speaker_encoder.pt
# Epoch 16/50: 100%|██████████| 6/6 [00:08<00:00,  1.48s/it, loss=0.999]
# Epoch 16 Average Loss: 0.9997
# Model saved to ../models/speaker_encoder.pt
# Epoch 17/50: 100%|██████████| 6/6 [00:08<00:00,  1.41s/it, loss=1]
# Epoch 17 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 18/50: 100%|██████████| 6/6 [00:08<00:00,  1.39s/it, loss=0.997]
# Epoch 18 Average Loss: 0.9996
# Model saved to ../models/speaker_encoder.pt
# Epoch 19/50: 100%|██████████| 6/6 [00:08<00:00,  1.44s/it, loss=1]
# Epoch 19 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 20/50: 100%|██████████| 6/6 [00:08<00:00,  1.38s/it, loss=1]
# Epoch 20 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 21/50: 100%|██████████| 6/6 [00:08<00:00,  1.40s/it, loss=1]
# Epoch 21 Average Loss: 1.0001
# Model saved to ../models/speaker_encoder.pt
# Epoch 22/50: 100%|██████████| 6/6 [00:08<00:00,  1.38s/it, loss=1]
# Epoch 22 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 23/50: 100%|██████████| 6/6 [00:08<00:00,  1.35s/it, loss=1]
# Epoch 23 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 24/50: 100%|██████████| 6/6 [00:08<00:00,  1.35s/it, loss=1]
# Epoch 24 Average Loss: 1.0003
# Model saved to ../models/speaker_encoder.pt
# Epoch 25/50: 100%|██████████| 6/6 [00:08<00:00,  1.37s/it, loss=1]
# Epoch 25 Average Loss: 1.0002
# Model saved to ../models/speaker_encoder.pt
# Epoch 26/50: 100%|██████████| 6/6 [00:08<00:00,  1.37s/it, loss=1]
# Epoch 26 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 27/50: 100%|██████████| 6/6 [00:08<00:00,  1.36s/it, loss=1]
# Epoch 27 Average Loss: 1.0001
# Model saved to ../models/speaker_encoder.pt
# Epoch 28/50: 100%|██████████| 6/6 [00:07<00:00,  1.31s/it, loss=1]
# Epoch 28 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 29/50: 100%|██████████| 6/6 [00:07<00:00,  1.33s/it, loss=1]
# Epoch 29 Average Loss: 0.9998
# Model saved to ../models/speaker_encoder.pt
# Epoch 30/50: 100%|██████████| 6/6 [00:08<00:00,  1.34s/it, loss=1]
# Epoch 30 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 31/50: 100%|██████████| 6/6 [00:08<00:00,  1.37s/it, loss=0.999]
# Epoch 31 Average Loss: 0.9993
# Model saved to ../models/speaker_encoder.pt
# Epoch 32/50: 100%|██████████| 6/6 [00:07<00:00,  1.32s/it, loss=1]
# Epoch 32 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 33/50: 100%|██████████| 6/6 [00:08<00:00,  1.37s/it, loss=1]
# Epoch 33 Average Loss: 1.0001
# Model saved to ../models/speaker_encoder.pt
# Epoch 34/50: 100%|██████████| 6/6 [00:07<00:00,  1.32s/it, loss=1]
# Epoch 34 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 35/50: 100%|██████████| 6/6 [00:07<00:00,  1.33s/it, loss=1]
# Epoch 35 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 36/50: 100%|██████████| 6/6 [00:07<00:00,  1.32s/it, loss=1]
# Epoch 36 Average Loss: 1.0000
# Model saved to ../models/speaker_encoder.pt
# Epoch 37/50: 100%|██████████| 6/6 [00:07<00:00,  1.33s/it, loss=0.998]
# Epoch 37 Average Loss: 0.9995
# Model saved to ../models/speaker_encoder.pt
# Epoch 38/50: 100%|██████████| 6/6 [00:07<00:00,  1.30s/it, loss=1]
# Epoch 38 Average Loss: 0.9993
# Model saved to ../models/speaker_encoder.pt
# Epoch 39/50: 100%|██████████| 6/6 [00:07<00:00,  1.30s/it, loss=1]
# Epoch 39 Average Loss: 0.9993
# Model saved to ../models/speaker_encoder.pt
# Epoch 40/50: 100%|██████████| 6/6 [00:08<00:00,  1.34s/it, loss=0.996]
# Epoch 40 Average Loss: 0.9989
# Model saved to ../models/speaker_encoder.pt
# Epoch 41/50: 100%|██████████| 6/6 [00:07<00:00,  1.32s/it, loss=1.01]
# Epoch 41 Average Loss: 1.0013
# Model saved to ../models/speaker_encoder.pt
# Epoch 42/50: 100%|██████████| 6/6 [00:07<00:00,  1.30s/it, loss=1]
# Epoch 42 Average Loss: 0.9995
# Model saved to ../models/speaker_encoder.pt
# Epoch 43/50: 100%|██████████| 6/6 [00:08<00:00,  1.34s/it, loss=0.997]
# Epoch 43 Average Loss: 0.9997
# Model saved to ../models/speaker_encoder.pt
# Epoch 44/50: 100%|██████████| 6/6 [00:08<00:00,  1.34s/it, loss=1]
# Epoch 44 Average Loss: 1.0003
# Model saved to ../models/speaker_encoder.pt
# Epoch 45/50: 100%|██████████| 6/6 [00:07<00:00,  1.29s/it, loss=1]
# Epoch 45 Average Loss: 0.9993
# Model saved to ../models/speaker_encoder.pt
# Epoch 46/50: 100%|██████████| 6/6 [00:07<00:00,  1.31s/it, loss=1]
# Epoch 46 Average Loss: 1.0001
# Model saved to ../models/speaker_encoder.pt
# Epoch 47/50: 100%|██████████| 6/6 [00:07<00:00,  1.33s/it, loss=1]
# Epoch 47 Average Loss: 1.0010
# Model saved to ../models/speaker_encoder.pt
# Epoch 48/50: 100%|██████████| 6/6 [00:07<00:00,  1.30s/it, loss=0.998]
# Epoch 48 Average Loss: 0.9992
# Model saved to ../models/speaker_encoder.pt
# Epoch 49/50: 100%|██████████| 6/6 [00:07<00:00,  1.31s/it, loss=0.998]
# Epoch 49 Average Loss: 0.9994
# Model saved to ../models/speaker_encoder.pt
# Epoch 50/50: 100%|██████████| 6/6 [00:07<00:00,  1.30s/it, loss=1]
# Epoch 50 Average Loss: 0.9997
# Model saved to ../models/speaker_encoder.pt
