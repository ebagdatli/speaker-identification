# %% [markdown]
# # Model Training
# Train the Speaker Encoder using Triplet Loss.

# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('..'))

from src.training.train import train
# Out:
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:12: UserWarning: audiomentations not found. Data augmentation will be disabled.
#   warnings.warn("audiomentations not found. Data augmentation will be disabled.", UserWarning)

# %%
# Configuration
DATA_PATH = "../data/raw"
MODEL_PATH = "../models/speaker_encoder_v2.pt"
EPOCHS = 50
BATCH_SIZE = 4

# Start Training
if os.path.exists(DATA_PATH) and len(os.listdir(DATA_PATH)) > 0:
    train(DATA_PATH, MODEL_PATH, EPOCHS, BATCH_SIZE)
else:
    print("Please add data to data/raw first.")
# Out:
# Using device: cpu
# Dataset Split: 59 Training, 6 Validation files.
# Starting training for 50 epochs...
# Epoch 1/50 [Train]:   0%|          | 0/14 [00:00<?, ?it/s]C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:105: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:105: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:105: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
# ...
