# %% [markdown]
# # Model Training
# Train the Speaker Encoder using Triplet Loss.

# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('..'))

from src.training.train import train

# %%
# Configuration
DATA_PATH = "../data/raw"
MODEL_PATH = "../models/speaker_encoder.pt"
EPOCHS = 20
BATCH_SIZE = 4

# Start Training
if os.path.exists(DATA_PATH) and len(os.listdir(DATA_PATH)) > 0:
    train(DATA_PATH, MODEL_PATH, EPOCHS, BATCH_SIZE)
else:
    print("Please add data to data/raw first.")
# Out:
# Using device: cpu
# Starting training for 20 epochs...
# Epoch 1/20:   0%|          | 0/5 [00:00<?, ?it/s]C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:25: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:25: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:25: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# Epoch 1/20: 100%|██████████| 5/5 [00:24<00:00,  4.82s/it, loss=1.11]
# Epoch 1 Average Loss: 1.0188
# Model saved to ../models/speaker_encoder.pt
# Epoch 2/20: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it, loss=0.946]
# Epoch 2 Average Loss: 0.9635
# Model saved to ../models/speaker_encoder.pt
# Epoch 3/20: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it, loss=0.671]
# Epoch 3 Average Loss: 0.8799
# Model saved to ../models/speaker_encoder.pt
# Epoch 4/20: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it, loss=0.937]
# Epoch 4 Average Loss: 0.9747
# Model saved to ../models/speaker_encoder.pt
# Epoch 5/20: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it, loss=0.957]
# Epoch 5 Average Loss: 0.9503
# Model saved to ../models/speaker_encoder.pt
# Epoch 6/20: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it, loss=1.06]
# Epoch 6 Average Loss: 0.8515
# Model saved to ../models/speaker_encoder.pt
# Epoch 7/20: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it, loss=1]
# Epoch 7 Average Loss: 0.9728
# Model saved to ../models/speaker_encoder.pt
# Epoch 8/20: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it, loss=0.983]
# Epoch 8 Average Loss: 0.9896
# Model saved to ../models/speaker_encoder.pt
# Epoch 9/20: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it, loss=0.975]
# Epoch 9 Average Loss: 0.9961
# Model saved to ../models/speaker_encoder.pt
# Epoch 10/20: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it, loss=1.01]
# Epoch 10 Average Loss: 0.9977
# Model saved to ../models/speaker_encoder.pt
# Epoch 11/20: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it, loss=0.996]
# Epoch 11 Average Loss: 0.9961
# Model saved to ../models/speaker_encoder.pt
# Epoch 12/20: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it, loss=0.945]
# Epoch 12 Average Loss: 0.9784
# Model saved to ../models/speaker_encoder.pt
# Epoch 13/20: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it, loss=0.877]
# Epoch 13 Average Loss: 0.9714
# Model saved to ../models/speaker_encoder.pt
# Epoch 14/20: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it, loss=1.25]
# Epoch 14 Average Loss: 1.0145
# Model saved to ../models/speaker_encoder.pt
# Epoch 15/20: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it, loss=1.01]
# Epoch 15 Average Loss: 0.9889
# Model saved to ../models/speaker_encoder.pt
# Epoch 16/20: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it, loss=0.999]
# Epoch 16 Average Loss: 0.9929
# Model saved to ../models/speaker_encoder.pt
# Epoch 17/20: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it, loss=0.999]
# Epoch 17 Average Loss: 0.9945
# Model saved to ../models/speaker_encoder.pt
# Epoch 18/20: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it, loss=0.986]
# Epoch 18 Average Loss: 0.9966
# Model saved to ../models/speaker_encoder.pt
# Epoch 19/20: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it, loss=0.977]
# Epoch 19 Average Loss: 0.9974
# Model saved to ../models/speaker_encoder.pt
# Epoch 20/20: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it, loss=1]
# Epoch 20 Average Loss: 0.9965
# Model saved to ../models/speaker_encoder.pt
