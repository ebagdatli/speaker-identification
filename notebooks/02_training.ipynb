# %% [markdown]
# # Model Training
# Train the Speaker Encoder using Triplet Loss.

# %%
import sys
import os

# Add project root to path
sys.path.append(os.path.abspath('..'))

from src.training.train import train

# %%
# Configuration
DATA_PATH = "../data/raw"
MODEL_PATH = "../models/speaker_encoder.pt"
EPOCHS = 20
BATCH_SIZE = 4

# Start Training
if os.path.exists(DATA_PATH) and len(os.listdir(DATA_PATH)) > 0:
    train(DATA_PATH, MODEL_PATH, EPOCHS, BATCH_SIZE)
else:
    print("Please add data to data/raw first.")
# Out:
# Using device: cpu
# Starting training for 20 epochs...
# Epoch 1/20:   0%|          | 0/2 [00:00<?, ?it/s]C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:25: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:25: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# C:\projects\sound-fingerprinting\speaker-identification\src\audio\preprocessing.py:25: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   total_duration = librosa.get_duration(filename=path)
# Epoch 1/20: 100%|██████████| 2/2 [00:05<00:00,  2.57s/it, loss=0.988]
# Epoch 1 Average Loss: 1.0128
# Model saved to ../models/speaker_encoder.pt
# Epoch 2/20: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s, loss=1.06]
# Epoch 2 Average Loss: 0.9992
# Model saved to ../models/speaker_encoder.pt
# Epoch 3/20: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s, loss=0.997]
# Epoch 3 Average Loss: 0.9962
# Model saved to ../models/speaker_encoder.pt
# Epoch 4/20: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s, loss=1]
# Epoch 4 Average Loss: 0.9996
# Model saved to ../models/speaker_encoder.pt
# Epoch 5/20: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s, loss=0.993]
# Epoch 5 Average Loss: 0.9947
# Model saved to ../models/speaker_encoder.pt
# Epoch 6/20: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s, loss=1]
# Epoch 6 Average Loss: 0.9997
# Model saved to ../models/speaker_encoder.pt
# Epoch 7/20: 100%|██████████| 2/2 [00:01<00:00,  1.25it/s, loss=1]
# Epoch 7 Average Loss: 1.0016
# Model saved to ../models/speaker_encoder.pt
# Epoch 8/20: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s, loss=0.997]
# Epoch 8 Average Loss: 0.9985
# Model saved to ../models/speaker_encoder.pt
# Epoch 9/20: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s, loss=1]
# Epoch 9 Average Loss: 1.0007
# Model saved to ../models/speaker_encoder.pt
# Epoch 10/20: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s, loss=1.01]
# Epoch 10 Average Loss: 1.0023
# Model saved to ../models/speaker_encoder.pt
# Epoch 11/20: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s, loss=0.997]
# Epoch 11 Average Loss: 0.9977
# Model saved to ../models/speaker_encoder.pt
# Epoch 12/20: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s, loss=0.988]
# Epoch 12 Average Loss: 0.9950
# Model saved to ../models/speaker_encoder.pt
# Epoch 13/20: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s, loss=1]
# Epoch 13 Average Loss: 0.9999
# Model saved to ../models/speaker_encoder.pt
# Epoch 14/20: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s, loss=1.01]
# Epoch 14 Average Loss: 1.0027
# Model saved to ../models/speaker_encoder.pt
# Epoch 15/20: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s, loss=0.995]
# Epoch 15 Average Loss: 0.9951
# Model saved to ../models/speaker_encoder.pt
# Epoch 16/20: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s, loss=1]
# Epoch 16 Average Loss: 1.0017
# Model saved to ../models/speaker_encoder.pt
# Epoch 17/20: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s, loss=1.01]
# Epoch 17 Average Loss: 1.0063
# Model saved to ../models/speaker_encoder.pt
# Epoch 18/20: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s, loss=1.01]
# Epoch 18 Average Loss: 1.0057
# Model saved to ../models/speaker_encoder.pt
# Epoch 19/20: 100%|██████████| 2/2 [00:01<00:00,  1.06it/s, loss=0.997]
# Epoch 19 Average Loss: 0.9964
# Model saved to ../models/speaker_encoder.pt
# Epoch 20/20: 100%|██████████| 2/2 [00:01<00:00,  1.19it/s, loss=0.997]
# Epoch 20 Average Loss: 0.9966
# Model saved to ../models/speaker_encoder.pt
