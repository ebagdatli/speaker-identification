# %% [markdown]
# # Speaker Identification Inference
# Test the system with new audio files.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.inference.identify_speaker import SpeakerIdentifier

# %%
identifier = SpeakerIdentifier(model_path="../models/speaker_encoder.pt", embeddings_path="../embeddings/speakers.json")

# Define a test file path
test_file = "../data/raw/02/alpay1.wav" # CHANGE THIS to test file

if os.path.exists(test_file):
    result = identifier.identify(test_file)
    print("Result:", result)
else:
    print(f"Test file {test_file} not found. Please set 'test_file' variable to a valid path.")
# Out:
# Result: {'speaker': '02', 'confidence': 1.0}
